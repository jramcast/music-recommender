# %%
import os
import sys
sys.path.insert(
    0,
    ".."
)

# %% [markdown]
# Supporting code for MSD is in https://github.com/tbertinmahieux/MSongsDB http://millionsongdataset.com/pages/code/#python

# %%
import pandas as pd

# %%
songs = pd.read_csv("../data/msdchallenge/msd.csv")

# %%
songs.head()
# Out:
#              track_id           artist_id  \
# 0  TRBHORD128F423DEF9  AR4R9BI1187FB44767
# 1  TRBHOYO12903C9C917  ARBEOHF1187B9B044D
# 2  TRBHOTH128F149A01B  ARQCHDN1187FB4C7C2
# 3  TRBHONF12903D00664  ARKEBNJ126E2B3BF7E
# 4  TRBHOYJ128F4292B75  ARXLOGT1187FB45068
#
#                             artist_mbid  \
# 0  946a3be7-bd99-47ac-8414-515c85811f40
# 1  79239441-bfd5-4981-a70c-55c3f15c1287
# 2  f926459e-1bd2-42a6-a174-8994ad950591
# 3                                   NaN
# 4  288af6c6-e5b7-4b2b-8f30-d164a05fa6a3
#
#                                        artist_name  \
# 0                                            Earth
# 1                                          Madonna
# 2  Luiz Bonfa / Oscar Castro Neves / Lalo Schifrin
# 3                                         Théophil
# 4                                   Jennifer Brown
#
#                                                title         artist_location  \
# ...

# %%
songs.describe()
# Out:
#            hotness  familiarity  danceability     duration  energy  \
# count  2000.000000  1999.000000        2000.0  2000.000000  2000.0
# mean      0.385239     0.565017           0.0   240.464657     0.0
# std       0.145764     0.163607           0.0   125.007654     0.0
# min       0.000000     0.000000           0.0     1.227300     0.0
# 25%       0.327134     0.468080           0.0   175.255060     0.0
# 50%       0.384611     0.564129           0.0   223.385670     0.0
# 75%       0.455092     0.664808           0.0   275.970160     0.0
# max       1.082503     1.000000           0.0  1819.767710     0.0
#
#           loudness         year        tempo  analysis_rate  end_of_fade_in  \
# count  2000.000000  2000.000000  2000.000000         2000.0     2000.000000
# mean    -10.444808   916.637000   123.919877        22050.0        0.735474
# std       5.316393   995.433936    35.714782            0.0        1.824849
# ...
